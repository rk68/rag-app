# %%
import pandas as pd

# %%
df = pd.read_csv('qa_dataset.csv')
df
# Out:
#      Unnamed: 0                                           question  \
# 0             0  Can an employer or agency use an automated emp...
# 1             1  What are the notification requirements of loca...
# 2             2  Can imputed or inferred data be used for a bia...
# 3             3  What is the responsibility of an employer or e...
# 4             4  What information must be made publicly availab...
# ..          ...                                                ...
# 175         183  How can an employer or employment agency provi...
# 176         184  When must the notice about the use of an autom...
# 177         185   Who can conduct bias audits under local law 144?
# 178         187  What information must be included in the notic...
# 179         188                              What is a bias audit?
#
#                                                 answer
# 0    No, the law requires notification about the jo...
# ...
